# %%
import matplotlib.pyplot as plt
import numpy as np

pointssal = ([0,26.0], [24,25.0], [48,27.0], [120,28.0], [168,29.0], [216,28.0], [312,25.0], [384,26.0],[480,27.0], [528,22.0], [648,28.0], [696,28.0])
pointstemp = ([0,24.6], [24,23.4], [48,25.9], [120,28.5], [168,24.0], [216,28.8], [312,27.7], [384,25.5],[480,26.7], [528,27.4], [648,25.2], [696,26.7])

x1, y1 = zip(*pointssal)
x2, y2 = zip(*pointstemp)

#plt.plot(x1, y1 ,'-ks', label = 'salinidade')
#plt.plot(x2, y2, '--k^', label = 'temperatura')

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.plot(x1, y1 ,'-ks', label = 'salinidade')
ax.plot(x2, y2, '--k^', label = 'temperatura')

plt.xticks(np.arange(min(x1), max(x1)+1, 24.0))
plt.yticks(np.arange(min(y1), max(y1)+1, 1.0))

plt.legend()

plt.xlim(0,696)

fig.savefig('AlgalTraps_sal_temp.png', dpi = 300)
