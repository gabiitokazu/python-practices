# %%
import matplotlib.pyplot as plt
import numpy as np

pointspH = ([0,6.86], [24,6.91], [48,6.90], [120,6.89], [168,6.61], [216,6.7], [312,6.81], [384,7.07],[480,6.89], [528,7.06], [648,7.03], [696,6.94])
pointsturb = ([0,2.21], [24,2.31], [48,2.29], [120,2.19], [168,1.21], [216,1.98], [312,5.98], [384,12.87],[480,4.81], [528,2.99], [648,1.04], [696,5.03])

x1, y1 = zip(*pointspH)
x2, y2 = zip(*pointsturb)

#plt.plot(x1, y1 ,'-ks', label = 'pH')
#plt.plot(x2, y2, '--k^', label = 'turbidez')

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.plot(x1, y1 ,'-ks', label = 'pH')
ax.plot(x2, y2, '--k^', label = 'turbidez')

plt.xticks(np.arange(min(x1), max(x1)+1, 24.0))
plt.yticks(np.arange(min(y2), max(y2)+1, 1.0))

plt.legend()

plt.xlim(0,696)

fig.savefig('AlgalTraps_turb_pH.png', dpi = 300)
